# %%
import pandas as pd
from datetime import date, datetime,timedelta
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ### Criteria:
#
# - \# of guests
# - Time Span
# - \# of bedrooms (optional)
# - Area (optional)
# - \# of beds (optional)
# - Reviews (optional)

# %% [markdown]
# We start by first loading listings.csv. This contains all the information about each Airbnb listing.

# %%
listings = pd.read_csv('listings.csv')
listings
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (43,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              id                            listing_url       scrape_id  \
# 0          5570      https://www.airbnb.com/rooms/5570  20191121092222
# 1          8488      https://www.airbnb.com/rooms/8488  20191121092222
# 2         29967     https://www.airbnb.com/rooms/29967  20191121092222
# 3         38245     https://www.airbnb.com/rooms/38245  20191121092222
# 4         39516     https://www.airbnb.com/rooms/39516  20191121092222
# ...         ...                                    ...             ...
# 13569  40262803  https://www.airbnb.com/rooms/40262803  20191121092222
# 13570  40264502  https://www.airbnb.com/rooms/40264502  20191121092222
# 13571  40265392  https://www.airbnb.com/rooms/40265392  20191121092222
# 13572  40265432  https://www.airbnb.com/rooms/40265432  20191121092222
# 13573  40267247  https://www.airbnb.com/rooms/40267247  20191121092222
#
#       last_scraped                                               name  \
# 0       2019-11-21                      Ocean front condo on the sand
# 1       2019-11-21                Juniper Zen Palace- SD's Best Hood!
# 2       2019-11-21                   Great home, 10 min walk to Beach
# 3       2019-11-21                     Point Loma/Liberty Station-NTC
# 4       2019-11-21                    Art Studio Retreat/Rustic Cabin
# ...            ...                                                ...
# 13569   2019-11-21                                  SAE GYPSY bedroom
# 13570   2019-11-21                         Charming Neighborhood Home
# 13571   2019-11-21                 Mission valley apartment San Diego
# 13572   2019-11-21                   Beautiful Central San Diego Home
# 13573   2019-11-21  Pacific Beach Getaway (private room w/ full size)
#
#                                                  summary  \
# 0      Missionbeachretreat.   Great Ocean Front Condo...
# 1      Walk every where in San Diegos most charming a...
# 2      This 2 bedroom, 2 full bathroom home offers al...
# 3      Stay in a 1928 Spanish Style home.  Den is dow...
# 4      We love having explorers from all over the wor...
# ...                                                  ...
# 13569                                                NaN
# 13570  Located in a peaceful, central & safe neighbor...
# 13571                                                NaN
# 13572  Welcome to sunny San Diego! This condo is clos...
# 13573  Perfect for the beach, nightlife, rest and rel...
#
#                                                    space  \
# 0      This charming two bedroom beachfront condomini...
# 1      Private craftsman home in the heart of Histori...
# 2      This two bedroom (1 CA king bed, 1 queen bed),...
# 3      Please note:  1928 home; remodeled in 2015. Co...
# 4      Nestled in South/North Park, a gentrified neig...
# ...                                                  ...
# 13569                                                NaN
# 13570  The house is newly remodeled, with hardwood fl...
# 13571                                                NaN
# 13572  Nestled in the hub of Mission Valley East, thi...
# 13573  Private room in a beautiful, clean, and spacio...
#
#                                              description experiences_offered  \
# 0      Missionbeachretreat.   Great Ocean Front Condo...                none
# 1      Walk every where in San Diegos most charming a...                none
# 2      This 2 bedroom, 2 full bathroom home offers al...                none
# 3      Stay in a 1928 Spanish Style home.  Den is dow...                none
# 4      We love having explorers from all over the wor...                none
# ...                                                  ...                 ...
# 13569                                                NaN                none
# 13570  Located in a peaceful, central & safe neighbor...                none
# 13571                                                NaN                none
# 13572  Welcome to sunny San Diego! This condo is clos...                none
# 13573  Perfect for the beach, nightlife, rest and rel...                none
#
#                                    neighborhood_overview  \
# 0      While some may compare San Diego’s Mission Bea...
# 1      South Park is a charming community and our nei...
# 2                                                    NaN
# 3      This neighborhood is an expensive, high-end Po...
# 4      We love our eclectic neighborhood, with a smal...
# ...                                                  ...
# 13569                                                NaN
# 13570  Peaceful & safe, this charming neighborhood is...
# 13571                                                NaN
# 13572  Located in in Mission Valley East, it's the pe...
# 13573                                                NaN
#
#                                                    notes  \
# 0                                                    NaN
# 1      we have no cable tv. just streaming services. ...
# 2                                                    NaN
# 3      I have a puppy now:  April 10th.  Lindbergh Fi...
# 4      There's no need to miss your exercise plan whi...
# ...                                                  ...
# 13569                                                NaN
# 13570  PAY LESS UPFRONT FEATURE The Pay Less Upfront ...
# 13571                                                NaN
# 13572                                                NaN
# 13573                                                NaN
#
#                                                  transit  \
# 0      Bus #8 goes to La Jolla and Old Town transit c...
# 1              bus route  to downtown is 1/2 block away!
# 2                                                    NaN
# 3      Public transit is across the street (100 meter...
# 4      If you enjoy a good hearty walk,  (1 mile) you...
# ...                                                  ...
# 13569                                                NaN
# 13570  Minutes away from both major freeways, the I-5...
# 13571                                                NaN
# 13572  All modes of transportation are ideal at this ...
# 13573                                                NaN
#
#                                                   access  \
# 0      2 Bedrooms (1 Queen, 2 Twins)  1 Bath Balcony ...
# 1                                               backyard
# 2                                                    NaN
# 3      Guests can sit in the dining room to eat or re...
# 4      Pool opens April, as weather allows Patio by A...
# ...                                                  ...
# 13569                                                NaN
# 13570  The whole property is available for our guests...
# 13571                                                NaN
# 13572                                                NaN
# 13573                                                NaN
#
#                                              interaction  \
# 0      Once reservation is made I will call guest.  I...
# 1                                                    NaN
# 2                                                    NaN
# 3      I can meet and greet you; once in a while; ano...
# 4      We take the lead from our guests. When our sid...
# ...                                                  ...
# 13569                                                NaN
# 13570  I've personally have traveled to many destinat...
# 13571                                                NaN
# 13572  While I won't be available, I do have experien...
# 13573                                                NaN
#
#                                              house_rules  thumbnail_url  \
# 0      Min 4 nights winter.  7 nights Spring Break, l...            NaN
# 1      • Check-in time is 3PM. We are fun, easygoing ...            NaN
# 2      This is not a party house. This is a quiet fam...            NaN
# 3      No drugs.      light alcohol is fine.    No sm...            NaN
# 4      This is a retreat-like setting and peacefulnes...            NaN
# ...                                                  ...            ...
# 13569                                                NaN            NaN
# 13570                                                NaN            NaN
# 13571                       No parties or big gatherings            NaN
# 13572  No wearing shoes in the home or additional gue...            NaN
# 13573                                                NaN            NaN
#
#        medium_url                                        picture_url  \
# 0             NaN  https://a0.muscache.com/im/pictures/d3342744-1...
# 1             NaN  https://a0.muscache.com/im/pictures/b1f12e62-1...
# 2             NaN  https://a0.muscache.com/im/pictures/76103867/c...
# 3             NaN  https://a0.muscache.com/im/pictures/f3073822-e...
# 4             NaN  https://a0.muscache.com/im/pictures/2ee5c482-c...
# ...           ...                                                ...
# 13569         NaN  https://a0.muscache.com/im/pictures/3eac4603-2...
# 13570         NaN  https://a0.muscache.com/im/pictures/9d0754b8-0...
# 13571         NaN  https://a0.muscache.com/im/pictures/4771b9bd-4...
# 13572         NaN  https://a0.muscache.com/im/pictures/ff63b2f7-a...
# 13573         NaN  https://a0.muscache.com/im/pictures/46072239-8...
#
#        xl_picture_url    host_id                                     host_url  \
# 0                 NaN       8435       https://www.airbnb.com/users/show/8435
# 1                 NaN      25186      https://www.airbnb.com/users/show/25186
# 2                 NaN     129123     https://www.airbnb.com/users/show/129123
# 3                 NaN     164137     https://www.airbnb.com/users/show/164137
# 4                 NaN     169649     https://www.airbnb.com/users/show/169649
# ...               ...        ...                                          ...
# 13569             NaN  283886496  https://www.airbnb.com/users/show/283886496
# 13570             NaN  311020875  https://www.airbnb.com/users/show/311020875
# 13571             NaN   32936357   https://www.airbnb.com/users/show/32936357
# 13572             NaN  267877980  https://www.airbnb.com/users/show/267877980
# 13573             NaN   20666876   https://www.airbnb.com/users/show/20666876
#
#              host_name  host_since                           host_location  \
# 0          Jef Karchin  2009-02-23    San Diego, California, United States
# 1               Helene  2009-07-10  Los Angeles, California, United States
# 2              Michael  2010-05-21    San Diego, California, United States
# 3              Melinda  2010-07-12    San Diego, California, United States
# 4      Chris  And Jean  2010-07-17    San Diego, California, United States
# ...                ...         ...                                     ...
# 13569         Fernando  2019-08-08                                      US
# 13570        Lorenzo'S  2019-11-20                                      US
# 13571           Amanda  2015-05-08    San Diego, California, United States
# 13572           Darryl  2019-06-11    San Diego, California, United States
# 13573             Karl  2014-08-28    San Diego, California, United States
#
#                                               host_about  host_response_time  \
# 0      Real estate broker,  Jef  Karchin real estate ...  within a few hours
# 1      HI! I am a photographer on tour. I have severa...      within an hour
# 2      We love living part of the year in San Diego. ...      within an hour
# 3      Hello Future and Returning Friends!   It is Sp...      within an hour
# 4      Jean is a grateful cancer survivor, activist, ...      within an hour
# ...                                                  ...                 ...
# 13569                                                NaN                 NaN
# 13570                                                NaN                 NaN
# 13571                                                NaN                 NaN
# 13572  Hi, my name is Darryl. I am a retired Navy vet...      within an hour
# 13573                                                NaN  within a few hours
#
#       host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                   100%                   NaN                 f
# 1                   100%                   NaN                 f
# 2                   100%                   NaN                 f
# 3                   100%                   NaN                 f
# 4                   100%                   NaN                 t
# ...                  ...                   ...               ...
# 13569                NaN                   NaN                 f
# 13570                NaN                   NaN                 f
# 13571                NaN                   NaN                 f
# 13572                91%                   NaN                 f
# 13573               100%                   NaN                 t
#
#                                       host_thumbnail_url  \
# 0      https://a0.muscache.com/im/users/8435/profile_...
# 1      https://a0.muscache.com/im/pictures/user/b83cc...
# 2      https://a0.muscache.com/im/users/129123/profil...
# 3      https://a0.muscache.com/im/users/164137/profil...
# 4      https://a0.muscache.com/im/users/169649/profil...
# ...                                                  ...
# 13569  https://a0.muscache.com/im/pictures/user/c5011...
# 13570  https://a0.muscache.com/im/pictures/user/70f5f...
# 13571  https://a0.muscache.com/im/pictures/user/6eed2...
# 13572  https://a0.muscache.com/im/pictures/user/9de83...
# 13573  https://a0.muscache.com/im/users/20666876/prof...
#
#                                         host_picture_url  host_neighbourhood  \
# 0      https://a0.muscache.com/im/users/8435/profile_...       Mission Beach
# 1      https://a0.muscache.com/im/pictures/user/b83cc...          Burlingame
# 2      https://a0.muscache.com/im/users/129123/profil...       Pacific Beach
# 3      https://a0.muscache.com/im/users/164137/profil...         Loma Portal
# 4      https://a0.muscache.com/im/users/169649/profil...          North Park
# ...                                                  ...                 ...
# 13569  https://a0.muscache.com/im/pictures/user/c5011...  Point Loma Heights
# 13570  https://a0.muscache.com/im/pictures/user/70f5f...                 NaN
# 13571  https://a0.muscache.com/im/pictures/user/6eed2...                 NaN
# 13572  https://a0.muscache.com/im/pictures/user/9de83...          Grantville
# 13573  https://a0.muscache.com/im/users/20666876/prof...       Pacific Beach
#
#        host_listings_count  host_total_listings_count  \
# 0                      3.0                        3.0
# 1                      4.0                        4.0
# 2                      6.0                        6.0
# 3                      3.0                        3.0
# 4                      1.0                        1.0
# ...                    ...                        ...
# 13569                  1.0                        1.0
# 13570                  1.0                        1.0
# 13571                  1.0                        1.0
# 13572                  0.0                        0.0
# 13573                  3.0                        3.0
#
#                                       host_verifications host_has_profile_pic  \
# 0                              ['email', 'phone', 'kba']                    t
# 1      ['email', 'phone', 'facebook', 'reviews', 'off...                    t
# 2      ['email', 'phone', 'reviews', 'kba', 'work_ema...                    t
# 3                   ['email', 'phone', 'reviews', 'kba']                    t
# 4      ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# ...                                                  ...                  ...
# 13569  ['email', 'phone', 'offline_government_id', 'g...                    t
# 13570  ['phone', 'jumio', 'offline_government_id', 's...                    t
# 13571  ['email', 'phone', 'reviews', 'jumio', 'selfie...                    t
# 13572  ['email', 'phone', 'offline_government_id', 'g...                    t
# 13573  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
#
#       host_identity_verified                          street  neighbourhood  \
# 0                          t    San Diego, CA, United States  Mission Beach
# 1                          t    San Diego, CA, United States     South Park
# 2                          t    San Diego, CA, United States  Pacific Beach
# 3                          t    San Diego, CA, United States    Loma Portal
# 4                          t    San Diego, CA, United States     North Park
# ...                      ...                             ...            ...
# 13569                      f    San Diego, CA, United States            NaN
# 13570                      f  Chula Vista, CA, United States            NaN
# 13571                      t    San Diego, CA, United States            NaN
# 13572                      f    San Diego, CA, United States            NaN
# 13573                      t    San Diego, CA, United States            NaN
#
#       neighbourhood_cleansed  neighbourhood_group_cleansed         city state  \
# 0                Mission Bay                           NaN    San Diego    CA
# 1                 South Park                           NaN    San Diego    CA
# 2              Pacific Beach                           NaN    San Diego    CA
# 3                  Roseville                           NaN    San Diego    CA
# 4                North Hills                           NaN    San Diego    CA
# ...                      ...                           ...          ...   ...
# 13569            Loma Portal                           NaN    San Diego    CA
# 13570              Northwest                           NaN  Chula Vista    CA
# 13571             Grantville                           NaN    San Diego    CA
# 13572             Grantville                           NaN    San Diego    CA
# 13573          Pacific Beach                           NaN    San Diego    CA
#
#       zipcode     market   smart_location country_code        country  \
# 0       92109  San Diego    San Diego, CA           US  United States
# 1       92104  San Diego    San Diego, CA           US  United States
# 2       92109  San Diego    San Diego, CA           US  United States
# 3       92106  San Diego    San Diego, CA           US  United States
# 4       92104  San Diego    San Diego, CA           US  United States
# ...       ...        ...              ...          ...            ...
# 13569   92110  San Diego    San Diego, CA           US  United States
# 13570   91910  San Diego  Chula Vista, CA           US  United States
# 13571   92120  San Diego    San Diego, CA           US  United States
# 13572   92108  San Diego    San Diego, CA           US  United States
# 13573   92109  San Diego    San Diego, CA           US  United States
#
#        latitude  longitude is_location_exact property_type        room_type  \
# 0      32.78430 -117.25258                 t   Condominium  Entire home/apt
# 1      32.72839 -117.12824                 t         House  Entire home/apt
# 2      32.80724 -117.25630                 t      Bungalow  Entire home/apt
# 3      32.74202 -117.21870                 t         House     Private room
# 4      32.73188 -117.11918                 t    Tiny house  Entire home/apt
# ...         ...        ...               ...           ...              ...
# 13569  32.74860 -117.22715                 t         House      Shared room
# 13570  32.62782 -117.09092                 t         House  Entire home/apt
# 13571  32.78512 -117.09792                 f   Condominium  Entire home/apt
# 13572  32.78381 -117.11205                 t   Condominium  Entire home/apt
# 13573  32.80602 -117.25271                 t   Condominium     Private room
#
#        accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0                 6        1.0       2.0   4.0  Real Bed
# 1                 5        2.0       3.0   3.0  Real Bed
# 2                 8        2.0       2.0   3.0  Real Bed
# 3                 1        1.0       1.0   1.0  Real Bed
# 4                 2        1.0       1.0   1.0  Real Bed
# ...             ...        ...       ...   ...       ...
# 13569             2        1.0       1.0   1.0  Real Bed
# 13570            16        2.0       3.0   7.0  Real Bed
# 13571             2        1.0       1.0   1.0  Real Bed
# 13572             2        1.0       1.0   0.0  Real Bed
# 13573             2        1.0       1.0   1.0  Real Bed
#
#                                                amenities  square_feet  \
# 0      {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...        850.0
# 1      {TV,Internet,Wifi,Kitchen,"Free parking on pre...          NaN
# 2      {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...          NaN
# 3      {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN
# 4      {Internet,Wifi,Pool,Kitchen,"Pets live on this...        250.0
# ...                                                  ...          ...
# 13569  {Wifi,Pool,Kitchen,"Smoking allowed","Pets all...          NaN
# 13570  {TV,Wifi,Kitchen,"Free parking on premises","S...          NaN
# 13571  {TV,Wifi,"Air conditioning",Kitchen,"Free park...          NaN
# 13572  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN
# 13573  {TV,Internet,Wifi,Kitchen,"Free parking on pre...          NaN
#
#            price weekly_price monthly_price security_deposit cleaning_fee  \
# 0      $2,050.00          NaN           NaN          $500.00      $150.00
# 1        $225.00          NaN           NaN          $300.00      $175.00
# 2        $225.00          NaN     $2,900.00          $250.00       $80.00
# 3         $75.00      $310.00     $1,020.00          $100.00       $16.00
# 4         $74.00      $450.00           NaN              NaN       $25.00
# ...          ...          ...           ...              ...          ...
# 13569     $40.00          NaN           NaN              NaN          NaN
# 13570    $149.00          NaN           NaN              NaN      $149.00
# 13571    $130.00          NaN           NaN              NaN          NaN
# 13572     $72.00          NaN           NaN            $0.00       $40.00
# 13573     $60.00          NaN           NaN              NaN       $40.00
#
#        guests_included extra_people  minimum_nights  maximum_nights  \
# 0                    1        $0.00               3             365
# 1                    4       $50.00               3            1125
# 2                    6       $15.00               4             365
# 3                    1       $10.00               1              21
# 4                    1        $0.00               3               7
# ...                ...          ...             ...             ...
# 13569                1        $0.00               1             365
# 13570                2       $10.00               1            1125
# 13571                1        $0.00               3            1125
# 13572                1        $0.00               2            1125
# 13573                1        $0.00               1            1125
#
#        minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# 0                           3                       3                     365
# 1                           3                       3                    1125
# 2                           4                       4                     365
# 3                           1                       1                      21
# 4                           3                       3                       7
# ...                       ...                     ...                     ...
# 13569                       1                       1                     365
# 13570                       1                       2                    1125
# 13571                       3                       3                    1125
# 13572                       2                       2                    1125
# 13573                       1                       1                    1125
#
#        maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 0                         365                     3.0                   365.0
# 1                        1125                     3.0                  1125.0
# 2                         365                     4.0                   365.0
# 3                          21                     1.0                    21.0
# 4                           7                     3.0                     7.0
# ...                       ...                     ...                     ...
# 13569                     365                     1.0                   365.0
# 13570                    1125                     1.3                  1125.0
# 13571                    1125                     3.0                  1125.0
# 13572                    1125                     2.0                  1125.0
# 13573                    1125                     1.0                  1125.0
#
#       calendar_updated has_availability  availability_30  availability_60  \
# 0         2 months ago                t               12               20
# 1          5 weeks ago                t                6               20
# 2         3 months ago                t                0                0
# 3           5 days ago                t                0                1
# 4            yesterday                t               16               37
# ...                ...              ...              ...              ...
# 13569            today                t               23               53
# 13570            today                t                1                1
# 13571            today                t               14               33
# 13572            today                t               21               51
# 13573            today                t               28               58
#
#        availability_90  availability_365 calendar_last_scraped  \
# 0                   31               176            2019-11-21
# 1                   42               218            2019-11-21
# 2                    0               234            2019-11-21
# 3                   31               306            2019-11-21
# 4                   61               319            2019-11-21
# ...                ...               ...                   ...
# 13569               83               173            2019-11-21
# 13570               12               287            2019-11-21
# 13571               63               153            2019-11-21
# 13572               81                81            2019-11-21
# 13573               88                88            2019-11-21
#
#        number_of_reviews  number_of_reviews_ltm first_review last_review  \
# 0                      0                      0          NaN         NaN
# 1                     40                      0   2010-10-13  2016-03-24
# 2                     60                      0   2010-07-09  2018-08-09
# 3                    143                      6   2010-09-09  2019-10-20
# 4                    384                     45   2010-07-20  2019-10-28
# ...                  ...                    ...          ...         ...
# 13569                  0                      0          NaN         NaN
# 13570                  0                      0          NaN         NaN
# 13571                  0                      0          NaN         NaN
# 13572                  0                      0          NaN         NaN
# 13573                  0                      0          NaN         NaN
#
#        review_scores_rating  review_scores_accuracy  \
# 0                       NaN                     NaN
# 1                      97.0                     9.0
# 2                      98.0                    10.0
# 3                      86.0                     9.0
# 4                      98.0                    10.0
# ...                     ...                     ...
# 13569                   NaN                     NaN
# 13570                   NaN                     NaN
# 13571                   NaN                     NaN
# 13572                   NaN                     NaN
# 13573                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                            NaN                    NaN
# 1                            9.0                   10.0
# 2                           10.0                   10.0
# 3                            9.0                   10.0
# 4                           10.0                   10.0
# ...                          ...                    ...
# 13569                        NaN                    NaN
# 13570                        NaN                    NaN
# 13571                        NaN                    NaN
# 13572                        NaN                    NaN
# 13573                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 0                              NaN                     NaN
# 1                             10.0                    10.0
# 2                             10.0                    10.0
# 3                             10.0                     9.0
# 4                             10.0                    10.0
# ...                            ...                     ...
# 13569                          NaN                     NaN
# 13570                          NaN                     NaN
# 13571                          NaN                     NaN
# 13572                          NaN                     NaN
# 13573                          NaN                     NaN
#
#        review_scores_value requires_license license  \
# 0                      NaN                f     NaN
# 1                      9.0                f     NaN
# 2                     10.0                f     NaN
# 3                      9.0                f     NaN
# 4                     10.0                f     NaN
# ...                    ...              ...     ...
# 13569                  NaN                f     NaN
# 13570                  NaN                f     NaN
# 13571                  NaN                f     NaN
# 13572                  NaN                f     NaN
# 13573                  NaN                f     NaN
#
#                                       jurisdiction_names instant_bookable  \
# 0      {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                f
# 1      {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                f
# 2      {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                f
# 3      {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                f
# 4      {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                f
# ...                                                  ...              ...
# 13569  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                f
# 13570                                                NaN                t
# 13571  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                f
# 13572  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                t
# 13573  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                f
#
#       is_business_travel_ready          cancellation_policy  \
# 0                            f  strict_14_with_grace_period
# 1                            f  strict_14_with_grace_period
# 2                            f                     moderate
# 3                            f                     moderate
# 4                            f  strict_14_with_grace_period
# ...                        ...                          ...
# 13569                        f                     moderate
# 13570                        f  strict_14_with_grace_period
# 13571                        f                     flexible
# 13572                        f                     flexible
# 13573                        f                     moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 t                                t
# 2                                 f                                f
# 3                                 t                                t
# 4                                 t                                f
# ...                             ...                              ...
# 13569                             f                                f
# 13570                             f                                f
# 13571                             f                                f
# 13572                             f                                f
# 13573                             f                                f
#
#        calculated_host_listings_count  \
# 0                                   2
# 1                                   2
# 2                                   5
# 3                                   3
# 4                                   1
# ...                               ...
# 13569                               1
# 13570                               1
# 13571                               1
# 13572                               2
# 13573                               3
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                2
# 1                                                2
# 2                                                5
# 3                                                0
# 4                                                1
# ...                                            ...
# 13569                                            0
# 13570                                            1
# 13571                                            1
# 13572                                            2
# 13573                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 3
# 4                                                 0
# ...                                             ...
# 13569                                             0
# 13570                                             0
# 13571                                             0
# 13572                                             0
# 13573                                             3
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                                0                NaN
# 1                                                0               0.36
# 2                                                0               0.53
# 3                                                0               1.28
# 4                                                0               3.38
# ...                                            ...                ...
# 13569                                            1                NaN
# 13570                                            0                NaN
# 13571                                            0                NaN
# 13572                                            0                NaN
# 13573                                            0                NaN
#
# [13574 rows x 106 columns]

# %% [markdown]
# As seen there are over 100 columns. We'll clean Listings to only get the columns informaiton valueable to us.

# %%
listings = listings[['id','accommodates','bedrooms','beds', 'zipcode', 'review_scores_rating']]
listings.head()
# Out:
#       id  accommodates  bedrooms  beds zipcode  review_scores_rating
# 0   5570             6       2.0   4.0   92109                   NaN
# 1   8488             5       3.0   3.0   92104                  97.0
# 2  29967             8       2.0   3.0   92109                  98.0
# 3  38245             1       1.0   1.0   92106                  86.0
# 4  39516             2       1.0   1.0   92104                  98.0

# %% [markdown]
# From here we can filterout listings and collect only the ones that meet the user given criteria

# %% [markdown]
# filter_room_details is a function that takes in the criteria given by the user and returns a dataframe with only the rows that meet what we are looking for

# %%
# returns a df with rooms that meet room critera

def filter_room_details(df, num_guests, num_bedrooms, num_beds, area, review):
    
    # get rooms greater than max_num_guests
    df_filtered_room = df[(df['accommodates'] ==  num_guests) 
                        & (df['bedrooms']  >=  num_bedrooms)
                        & (df['beds']  >=  num_beds)
                        & (df['review_scores_rating']  >=  review)]
    
    # if area is given get rooms in area
    if area != 0:
        df_filtered_room = df_filtered_room.loc[df_filtered_room['zipcode']  ==  area]

    
    return df_filtered_room

# %% [markdown]
# Here we can test this function by finding all rooms with:
# - capacity for 8 guests
# - located in 92109
# - a review score greater than 80

# %%
num_guests = 4
zipcode = 92109
minimum_review = 80

df_filter_room_details_test = filter_room_details(listings, num_guests, 0, 0, zipcode, minimum_review)
df_filter_room_details_test
# Out:
#             id  accommodates  bedrooms  beds zipcode  review_scores_rating
# 47      182428             4       0.0   2.0   92109                  85.0
# 56      211583             4       2.0   3.0   92109                  97.0
# 121     495832             4       2.0   2.0   92109                  95.0
# 195     798077             4       2.0   4.0   92109                  82.0
# 207     839257             4       2.0   4.0   92109                  81.0
# ...        ...           ...       ...   ...     ...                   ...
# 7887  26033028             4       1.0   2.0   92109                  96.0
# 7935  26141092             4       1.0   2.0   92109                  89.0
# 8047  26423914             4       1.0   1.0   92109                  89.0
# 8063  26470537             4       1.0   2.0   92109                 100.0
# 8084  26518543             4       2.0   2.0   92109                  96.0
#
# [311 rows x 6 columns]

# %% [markdown]
# Next we need to filter the listings over the users given time span

# %% [markdown]
# We start by loading calendar.csv which contains information about each listing over a set of dates

# %%
calendar = pd.read_csv('calendar.csv')
calendar.head()
# Out:
#    listing_id        date available      price adjusted_price  minimum_nights  \
# 0        5570  2019-11-21         f  $2,050.00      $2,050.00               3
# 1        5570  2019-11-22         f  $2,050.00      $2,050.00               3
# 2        5570  2019-11-23         f  $2,050.00      $2,050.00               3
# 3        5570  2019-11-24         f  $2,050.00      $2,050.00               3
# 4        5570  2019-11-25         f  $2,050.00      $2,050.00               3
#
#    maximum_nights
# 0             365
# 1             365
# 2             365
# 3             365
# 4             365

# %% [markdown]
# Once again we will remove the unnecessary columns. This time we are only focused on  the data and the price of the listing.

# %% [markdown]
# We will also drop the rows with any missing elements

# %%
calendar = calendar[['listing_id','date','price']]
calendar.dropna()
calendar.head()
# Out:
#    listing_id        date      price
# 0        5570  2019-11-21  $2,050.00
# 1        5570  2019-11-22  $2,050.00
# 2        5570  2019-11-23  $2,050.00
# 3        5570  2019-11-24  $2,050.00
# 4        5570  2019-11-25  $2,050.00

# %% [markdown]
# Next we need to convert the price column from a string to an float

# %% [markdown]
# dollar_to_number converts a string with a dollar amount into a float

# %%
def dollar_to_number(string):
    string = string.replace('$', '')
    string = string.replace(',', '')
    string = string.replace('.', '')
    number = int(string)/100
    return number

#dollar_to_number('$2,050.00')

# %% [markdown]
# and then we apply the function to our dataframe

# %%
calendar['price'] = calendar['price'].apply(dollar_to_number)

# %% [markdown]
# Finally we will convert the date column to datetime objects

# %%
calendar['date'] = pd.to_datetime(calendar['date'])

# %% [markdown]
# Now we will take the dataframe from filter_room_details and the users given time frame inorder to gather the prices for each listing over the time span given

# %%
# returns a df with rooms that meet time critera

def filter_timespan(df_listings, df_calendar, start_date, end_date):
    
    # get a list of days in the timespan
    day_list = []
    day_count = (end_date - start_date).days + 1
    for day in [d for d in (start_date + timedelta(n) for n in range(day_count)) if d <= end_date]:
        day_list.append(day)
    
    # get listing ids from df_listings
    id_list = df_listings['id'].to_list()
    
    #remove ids from df_calendar that are not in id_list
    df_calendar_filtered = df_calendar[df_calendar['listing_id'].isin(id_list)]
    
    #remove dates from df_calendar that are not in day_list
    df_calendar_filtered = df_calendar[df_calendar['date'].isin(day_list)]
    
    # at this point calendar only contains the listings that meet our criteria
    # we can drop the listing_id column
    df_calendar_filtered = df_calendar_filtered.drop('listing_id', axis = 1)
    
    # group items by date and find the average price on that day
    df_calendar_filtered = df_calendar_filtered.groupby(['date']).mean()
    
    #convert and return as series
    series = pd.Series(df_calendar_filtered['price'])
    return series

# %% [markdown]
# Test to find the average prices between December and January

# %%
start_date = date(2019, 12, 1)
end_date = date(2020, 1, 31)

df_timeseries_test = filter_timespan(df_filter_room_details_test, calendar, start_date, end_date)
#df_timeseries_test

# %% [markdown]
# ## Now combined all together

# %%
def create_timeseries(df_listings, df_calendar, num_guests, start_date, end_date, min_num_bedrooms, min_num_beds, zipcode, minimum_review):
    
    df_room_details = filter_room_details(df_listings, num_guests, min_num_bedrooms, min_num_beds, zipcode, minimum_review)
    timeseries = filter_timespan(df_room_details, df_calendar, start_date, end_date)
    return timeseries

# %%
num_guests = 1
start_date = date(2018, 12, 31)
end_date = date(2020, 12, 31)

min_num_bedrooms = 0
min_num_beds = 0
zipcode = 0
minimum_review = 0

# %%
test_timeseries = create_timeseries(listings, calendar, num_guests, start_date, end_date, min_num_bedrooms, min_num_beds, zipcode, minimum_review)

# %%
lines = test_timeseries.plot.line()
lines
