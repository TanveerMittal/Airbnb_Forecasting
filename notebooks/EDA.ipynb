# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
plt.style.use("fivethirtyeight")

# %%
listings = pd.read_csv("data/listings.csv")
listings.head()
# Out:
# /home/tmittal/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (43,94) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       id                         listing_url       scrape_id last_scraped  \
# 0   5570   https://www.airbnb.com/rooms/5570  20191121092222   2019-11-21
# 1   8488   https://www.airbnb.com/rooms/8488  20191121092222   2019-11-21
# 2  29967  https://www.airbnb.com/rooms/29967  20191121092222   2019-11-21
# 3  38245  https://www.airbnb.com/rooms/38245  20191121092222   2019-11-21
# 4  39516  https://www.airbnb.com/rooms/39516  20191121092222   2019-11-21
#
#                                   name  \
# 0        Ocean front condo on the sand
# 1  Juniper Zen Palace- SD's Best Hood!
# 2     Great home, 10 min walk to Beach
# 3       Point Loma/Liberty Station-NTC
# 4      Art Studio Retreat/Rustic Cabin
#
#                                              summary  \
# 0  Missionbeachretreat.   Great Ocean Front Condo...
# 1  Walk every where in San Diegos most charming a...
# 2  This 2 bedroom, 2 full bathroom home offers al...
# 3  Stay in a 1928 Spanish Style home.  Den is dow...
# 4  We love having explorers from all over the wor...
#
#                                                space  \
# 0  This charming two bedroom beachfront condomini...
# 1  Private craftsman home in the heart of Histori...
# 2  This two bedroom (1 CA king bed, 1 queen bed),...
# 3  Please note:  1928 home; remodeled in 2015. Co...
# 4  Nestled in South/North Park, a gentrified neig...
#
#                                          description experiences_offered  \
# 0  Missionbeachretreat.   Great Ocean Front Condo...                none
# 1  Walk every where in San Diegos most charming a...                none
# 2  This 2 bedroom, 2 full bathroom home offers al...                none
# 3  Stay in a 1928 Spanish Style home.  Den is dow...                none
# 4  We love having explorers from all over the wor...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  While some may compare San Diego’s Mission Bea...  ...                f
# 1  South Park is a charming community and our nei...  ...                f
# 2                                                NaN  ...                f
# 3  This neighborhood is an expensive, high-end Po...  ...                f
# 4  We love our eclectic neighborhood, with a smal...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f                     moderate
# 3                        f                     moderate
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             f                                f
# 3                             t                                t
# 4                             t                                f
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               2
# 2                               5
# 3                               3
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            2
# 2                                            5
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            3
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0                NaN
# 1                                            0               0.36
# 2                                            0               0.53
# 3                                            0               1.28
# 4                                            0               3.38
#
# [5 rows x 106 columns]

# %%
listings.columns.to_list()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
listings.isnull().mean()[listings.isnull().mean() > 0]
# Out:
# summary                         0.033594
# space                           0.220200
# description                     0.019154
# neighborhood_overview           0.292545
# notes                           0.454693
# transit                         0.366657
# access                          0.378886
# interaction                     0.333211
# house_rules                     0.257846
# thumbnail_url                   1.000000
# medium_url                      1.000000
# xl_picture_url                  1.000000
# host_name                       0.000442
# host_since                      0.000442
# host_location                   0.003094
# host_about                      0.313099
# host_response_time              0.199425
# host_response_rate              0.199425
# host_acceptance_rate            1.000000
# host_is_superhost               0.000442
# host_thumbnail_url              0.000442
# host_picture_url                0.000442
# host_neighbourhood              0.143804
# host_listings_count             0.000442
# host_total_listings_count       0.000442
# host_has_profile_pic            0.000442
# host_identity_verified          0.000442
# neighbourhood                   0.035951
# neighbourhood_group_cleansed    1.000000
# state                           0.000368
# zipcode                         0.009356
# market                          0.001842
# bathrooms                       0.000295
# bedrooms                        0.001105
# beds                            0.001252
# square_feet                     0.987034
# weekly_price                    0.925077
# monthly_price                   0.935686
# security_deposit                0.199352
# cleaning_fee                    0.109400
# first_review                    0.160454
# last_review                     0.160454
# review_scores_rating            0.169736
# review_scores_accuracy          0.170031
# review_scores_cleanliness       0.169884
# review_scores_checkin           0.170694
# review_scores_communication     0.170031
# review_scores_location          0.170694
# review_scores_value             0.170841
# license                         0.996537
# jurisdiction_names              0.038235
# reviews_per_month               0.160454
# dtype: float64

# %%
calendar = pd.read_csv("data/calendar.csv")
calendar["date"] = pd.to_datetime(calendar["date"])
parse_price = lambda p: float(p.replace(",", "")[1:])
calendar["price"] = calendar["price"].apply(parse_price)
calendar["adjusted_price"] = calendar["adjusted_price"].apply(parse_price)
calendar.head()
# Out:
#    listing_id       date available   price  adjusted_price  minimum_nights  \
# 0        5570 2019-11-21         f  2050.0          2050.0               3
# 1        5570 2019-11-22         f  2050.0          2050.0               3
# 2        5570 2019-11-23         f  2050.0          2050.0               3
# 3        5570 2019-11-24         f  2050.0          2050.0               3
# 4        5570 2019-11-25         f  2050.0          2050.0               3
#
#    maximum_nights
# 0             365
# 1             365
# 2             365
# 3             365
# 4             365

# %%
calendar.isnull().mean()
# Out:
# listing_id        0.0
# date              0.0
# available         0.0
# price             0.0
# adjusted_price    0.0
# minimum_nights    0.0
# maximum_nights    0.0
# dtype: float64

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4954510 entries, 0 to 4954509
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            datetime64[ns]
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 264.6+ MB

# %%
fig = plt.figure(figsize=(10, 5))
months = mdates.MonthLocator()
months_fmt = mdates.DateFormatter('%b')
plt.gca().xaxis.set_major_locator(months)
plt.gca().xaxis.set_major_formatter(months_fmt)
avg_prices = calendar.groupby("date").mean()["price"]
plt.title("Average San Diego AirBnB Rental Prices vs. Month (2019-2020)")
plt.plot(avg_prices.index, avg_prices);
plt.savefig("plots/averagePrice.png")

# %%
# Out:
# date
# 2019-11-21    183.263518
# 2019-11-22    197.970900
# 2019-11-23    203.130838
# 2019-11-24    190.625313
# 2019-11-25    191.547959
#                  ...
# 2020-11-15    220.735745
# 2020-11-16    219.767865
# 2020-11-17    220.604685
# 2020-11-18    221.224400
# 2020-11-19    224.404523
# Name: price, Length: 365, dtype: float64
